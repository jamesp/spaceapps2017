# %%
# %matplotlib nbagg

import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %%
d = xr.open_dataset('monthly/seaice_conc_monthly_nh_f17_201511_v02r00.nc')

# %%
fig, ax = plt.subplots()
d.seaice_conc_monthly_cdr.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import os
import time

# %%
files = [os.path.join('monthly', f) for f in os.listdir('./monthly/')]

# %%
ds = xr.open_mfdataset(files)

# %%
fig, ax = plt.subplots()
for t in ds.time:
    ax.clear()
    ds.seaice_conc_monthly_cdr.sel(time=t).plot.contourf(add_colorbar=False, ax=ax)
    fig.canvas.draw()
    time.sleep(1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
d.seaice_conc_monthly_cdr.swap_dims({'ygrid': 'latitude', 'xgrid': 'longitude'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-8d894ff7cebc> in <module>()
# ----> 1 d.seaice_conc_monthly_cdr.swap_dims({'ygrid': 'latitude', 'xgrid': 'longitude'})
#
# /Users/jp/.anaconda3/envs/spaceapps/lib/python3.6/site-packages/xarray/core/dataarray.py in swap_dims(self, dims_dict)
#     849         Dataset.swap_dims
#     850         """
# --> 851         ds = self._to_temp_dataset().swap_dims(dims_dict)
#     852         return self._from_temp_dataset(ds)
#     853
#
# /Users/jp/.anaconda3/envs/spaceapps/lib/python3.6/site-packages/xarray/core/dataset.py in swap_dims(self, dims_dict, inplace)
#    1586                 raise ValueError('replacement dimension %r is not a 1D '
#    1587                                  'variable along the old dimension %r'
# -> 1588                                  % (v, k))
#    1589
# ...
